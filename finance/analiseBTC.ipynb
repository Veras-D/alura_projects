# %%
from matplotlib import pyplot as plt
import pandas as pd
import yfinance
plt.style.use('default')

# %%
carteira = ['BTC', 'ETH', 'NEAR', 'INJ', 'FLOW', 'FIL', 'RENDER', 'PEPE', 'AEVO', 'AAVE', 'OP']

# %%
n = 0  # Essa variavel deve ser alterada no Dashboard
crypto = yfinance.Ticker(carteira[n]+'-USD')
dados_crypto = crypto.history(period='max', interval='1d')
dados_crypto = dados_crypto.drop(['Dividends', 'Stock Splits'], axis=1)
dados_crypto = dados_crypto.dropna(inplace=True)
dados_crypto
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-04-23 00:00:00+00:00  66839.890625  67199.242188  65864.867188
# 2024-04-24 00:00:00+00:00  66408.718750  67075.367188  63589.871094
# 2024-04-25 00:00:00+00:00  64275.019531  65275.207031  62783.632812
# 2024-04-26 00:00:00+00:00  64485.371094  64789.656250  63322.398438
# 2024-04-27 00:00:00+00:00  63753.121094  63885.769531  62581.515625
#
#                                   Close       Volume
# Date
# 2014-09-17 00:00:00+00:00    457.334015     21056800
# ...

# %%
dados_crypto['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
dados_crypto[['Close', 'High', 'Low']].plot()
# Out:
# <Axes: xlabel='Date'>
